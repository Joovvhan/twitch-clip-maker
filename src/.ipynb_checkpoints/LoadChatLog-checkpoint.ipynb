# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Dec 12 23:33:06 2018

@author: Joowhan Song
"""

import glob
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from operator import itemgetter

# %%
#%%

chatLogName = glob.glob('..\\data\\*.txt')

timeFmt = '%H:%M:%S.%f'

timeStamps = list()
userIDs = list()
chats = list()

maxIdxNum = 5

# %%
# %%
with open(chatLogName[0], 'r', encoding='utf-8') as chatLog:
    for i, line in enumerate(chatLog):
        timeStr = line[line.find('[') + 1:line.find(']')]
        time = (datetime.strptime(timeStr, timeFmt) - datetime(1900,1,1)).total_seconds()
        # time = datetime.strptime(timeStr, timeFmt)
        
        chatStr = line[line.find(']') + 2:]
        userID = chatStr[:chatStr.find(':')]
        chat = chatStr[chatStr.find(':') + 1:chatStr.find('\n')]

        timeStamps.append(time)
        userIDs.append(userID)
        chats.append(chat)

# %%
# %%
plt.figure()
chatNum = np.asarray(range(1, len(timeStamps) + 1))
plt.plot(timeStamps, chatNum)
plt.show()

# %%
#%%
plt.figure(figsize=(12, 12))
chatHist = plt.hist(timeStamps, bins=np.int(timeStamps[-1] / 60))
plt.ylabel('Number of Chats')
plt.xlabel('Time(seconds)')
plt.show()

# %%
#%%

chatHistIndex = np.asarray(range(0, len(chatHist[0])))
chatHistSum = np.cumsum(chatHist[0])

#%%

# %%
plt.figure()
plt.plot(chatHist[0])
plt.show()

#%%
chatTable = np.stack([chatHist[0], chatHistIndex], axis=1)

#%%
chatTableSorted = np.asarray(sorted(chatTable, key = itemgetter(0), reverse=True))

#%%

# %%
averageLength = 60

plt.figure()
chatHistConv = np.convolve(chatHist[0], np.ones((averageLength,))/averageLength, mode='same')
# print(chatHistConv[-10:-1])
# chatHistMean = np.concatenate([chatHistConv, chatHist[0][-10:-1]])
chatHistMean = chatHistConv
plt.plot(chatHistMean)
plt.show()
print('Moving Average Length:{}\t Original Length:{}'.format(len(chatHistMean), len(chatHist[0])))
# Out:
# Moving Average Length:195	 Original Length:195

# %%
plt.figure(figsize = (12, 12))

plt.subplot(3, 1, 1)
plt.plot(chatHist[0])
plt.plot(chatHistMean)
chatHistDiff = chatHist[0] - chatHistMean
plt.plot(chatHist[0] - chatHistMean)

plt.subplot(3, 1, 2)
plt.plot(np.diff(chatHist[0]))

plt.subplot(3, 1, 3)
plt.plot(np.diff(np.diff(chatHist[0])))

plt.show()

# %%
plt.figure(figsize = (12, 4))
plt.plot(chatHistDiff)
baseLine = np.zeros((len(chatHistDiff), 1))
plt.plot(baseLine, 'r')
plt.show()

# %%
dist, bin_edges = np.histogram(chatHistDiff)
plt.hist(chatHistDiff, bins='auto')
meanChatNum = np.mean(chatHistDiff)
meanChatStd = np.std(chatHistDiff)
plt.plot([meanChatNum, meanChatNum], [0, max(dist)])
plt.plot([meanChatNum + 2 * meanChatStd, meanChatNum + 2 * meanChatStd], [0, max(dist)], color='r')
plt.plot([meanChatNum - 2 * meanChatStd, meanChatNum - 2 * meanChatStd], [0, max(dist)], color='r')

plt.show()

# %%
plt.figure(figsize = (12, 4))
plt.plot(chatHistDiff)
baseLine = np.zeros((len(chatHistDiff), 1))
meanLine = meanChatNum * np.ones((len(chatHistDiff), 1))
std2Line = meanLine + 2 * meanChatStd 

plt.plot(baseLine, 'r')
plt.plot(meanLine, 'orange')
plt.plot(std2Line, 'g')

idx = np.asarray(np.where(chatHistDiff > meanChatNum + 2 * meanChatStd)[0])
plt.plot(idx, chatHistDiff[idx], '*', color='r', markerSize=10)

plt.show()

# %%
print(idx)
# Out:
# [  2  26  27  28  39  41  70 167 177 184]

# %%
bundle = list()
firstIdx = idx[0]

for i in range(len(idx)):
    if i == len(idx) - 1 or (idx[i + 1] - idx[i] > 2):
        bundle.append(np.asarray(range(firstIdx, idx[i] + 1)))
        
        if i < len(idx) - 1:
            firstIdx = idx[i+1]

# %%
bundle
# Out:
# [array([2]),
#  array([26, 27, 28]),
#  array([39, 40, 41]),
#  array([70]),
#  array([167]),
#  array([177]),
#  array([184])]

# %%
import json

manifest = list()

for i in range(len(bundle)):
    startTime = int(bundle[i][0] * 60)
    
    if startTime < 0:
        startTime = 0
    
    videoLength = int(len(bundle[i]) * 60)
    
    videoName = 'new_video_{:0>2d}.mp4'.format(i)
        
    
    command = {"start_time": startTime, "length": videoLength, "rename_to": videoName}

    manifest.append(command)

with open('../manifest/manifest.json', 'w') as outfile:
    json.dump(manifest, outfile)

# %%
manifest
# Out:
# [{'length': 60, 'rename_to': 'new_video_00.mp4', 'start_time': 120},
#  {'length': 180, 'rename_to': 'new_video_01.mp4', 'start_time': 1560},
#  {'length': 180, 'rename_to': 'new_video_02.mp4', 'start_time': 2340},
#  {'length': 60, 'rename_to': 'new_video_03.mp4', 'start_time': 4200},
#  {'length': 60, 'rename_to': 'new_video_04.mp4', 'start_time': 10020},
#  {'length': 60, 'rename_to': 'new_video_05.mp4', 'start_time': 10620},
#  {'length': 60, 'rename_to': 'new_video_06.mp4', 'start_time': 11040}]

# %%
maxIdx = list()

for i in range(0, maxIdxNum):
    maxIdx.append(int(chatTableSorted[i, 1]))

maxIdx = np.asarray(maxIdx) 
#%%

plt.figure()
plt.plot(chatHist[0])
plt.plot(maxIdx, chatHist[0][maxIdx], 'o', markersize = 6)
plt.show()


underBound = list()
upperBound = list()

for i in range(0, maxIdxNum):
    underBound.append(chatHist[1][maxIdx[i]])
    upperBound.append(chatHist[1][maxIdx[i] + 1])


    
#%%
hotChats = list()

for i in range(0, maxIdxNum):
    booleanIdx = np.array((timeStamps > underBound[i]) & (timeStamps < upperBound[i]))
    hotChat = np.asarray(chats)[booleanIdx]
    hotChats.append(hotChat)
    
#%%

# %%
hotChats[3]
# Out:
# array([' 조졌네', ' 거른다', ' 조졌다', ' mar del japan 이네', ' 엌', ' ㅁㅊ이건...아..',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ogn에 얼렁 연락해야겠네 ㅋㅋ', ' 거른다', ' 해',
#        ' 오늘부터 포나 거릅니다', ' 거름 ㅅㄱ', ' 포나 안래', ' 거른다', ' 조졌다', ' 아이돌 출신ㅋㅋㅋ',
#        ' ㅈ트나이트...', ' 명', ' 믿고 거릅니다 ㅅㄱ영', ' ogn에 연락해여 빨리', ' ogn 망했네',
#        ' ㅈᆢ졌다', ' 거름 ㅅㄱ', ' 헐', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 진짜 죠졌다', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 포나 거른다', ' 해', ' 스페인어인듯??', ' 연락해야겠는데 ㅋㅋㅋㅋㅋㅋㅋㅋ', ' 관계자분한테 연락하죠',
#        ' 저걸 캐치 하시다니 ㅋㅋ', ' ㅈ트나이트', ' 해', ' 포나안함 ㅅㄱ', ' 포너 거른답',
#        ' 저건 조금 민감한데 ;', ' 믿고 거르내요 수고연', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 포나거름',
#        ' 뭐야 갑자기 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ogn조졌다 진자', ' 연락하는게 좋을것같음',
#        ' 저거 수정해야하는데 안그럼 난리남 ㅋㅋㅋㅋㅋ', ' 망.....', ' 빨리 말해줘야할텐데', ' ㄹㅇ',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 명', ' 갑분싸', ' ogn에 연락하자 얼른',
#        ' 저걸 발견하신분은 뭐지', ' ㅇㄱ ㄹㅇ', ' ㄷㄷ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 이거 맞음',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 포나 ogn 거른다', ' 포나 거른다', ' 예매취소함ㅅㄱ',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠ', ' 이게 걸려지네', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 일본해 쌉에반데 ;;', ' 저거 되게 민감한 사안인데', ' ㅈ트나이트', ' 좉트나이트 거른다',
#        ' 포나강제거름', ' 이거 ㄹㅇ 조졋네', ' 갑분싸 ;', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' [해당 스트리머의 의사와는 아무련 관련이 없습니다.]', ' 후닥 보고드려라', ' 이거 연락안하면 더 커질텐데',
#        ' 갑분싸', ' 지금 우정잉 당황했다 ㅋㅋㅋㅋㅋㅋ', ' 포나 거른다', ' 포나거른다',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 조짐의 시작을 알려주지',
#        ' 다시찍짜 하죠 ㅋㅋㅋㅋ', ' 민감한사안 ㅅㄱ', ' 난리났네', ' 갑분쌐ㅋㅋㅋㅋㅋ', ' 갑분싸',
#        ' 연락 해야하는거아님?', ' ㅋㅋㅋㅋㅋ', ' 빨리 연락해줘요', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 포나 점유율 바둑게임도 못이기지 않나', ' 포나....', ' !사과',
#        ' [3021번째 사과 ThankEgg ] 여러분 제가 실수를... 죄송합니다! 더 열심히 하겠습니다 충성충성 ^^7',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 갑분싸ㅋㅋㅋ', ' 당황', ' 조졌네;;',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 연락 빨리 해봐요', ' 거른다 포나', ' 조져따', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 갑분쌐ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 알려주는게 낫지 않나 한국 런칭 시작하는판에', ' 진짜 보고해됨', ' ㅋㅋㅋㅋ',
#        ' ㅋㅋㅋㅋ', ' Mala Dol Japan', ' 엌;', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' ㅋㅋㅋ ㄹㅇ 조졌다', ' 당-황', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 우정잉 당황', ' ㅋㅋㅋㅋㅋㅋ', ' 보고!', ' 핵 갑분싸인데',
#        ' 이거 시작인데', ' 빨리 얘기해야할듯;;', ' 지금 빨리 보고 해서 칭찬받으셈', ' 포나 거른다 진짜',
#        ' 큰일났네 ㄷ', ' 역시 포나 사랑 우정잉', ' 연락해야할듯', ' 부끄사하면 레전드', ' 보고',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 알아챈사람 대단하다 ㅋㅋㅋ', ' 갑분싸', ' 당ㅡㅡㅡㅡㅡ황',
#        ' 조졋다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 우부장이 보고 함', ' 진짜 당황했다 ㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' CJ가 그렇지 뭐', ' 포나 거르면대는거지?', ' ㅋㅋㅋㅋㅋㅋㅋ', ' 보고중', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 어차피 한국에서 포나 ㅈ망겜인데 우리나라가 거른다고 수정 안함 ㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' ㄹㅇ ㅋㅋㅋ....', ' 근데 리얼 연락 각이다 ㅋㅋㅋㅋ ㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㄹㅇ 조졌네', ' 이거 진짜 포나 시작인데', ' 당황당황',
#        ' 애 국 잉', ' 조졌따', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㄷㄷ', ' 빠른 대체 좋습니다',
#        ' 방송천재 ㅋㅋㅋㅋ', ' 2트가죠 ㅋㅋㅋ', ' 믿고거른다', ' ㅋㅋㅋㅋㅋ', ' 애 국 잉',
#        ' 포나세팅하시네 ㅋㅋ', ' 긴급상황', ' 일뽕CJ', ' 일본잉', ' 애국잉', ' 지휘계통으로 보고',
#        ' 우정잉가산점', ' 아니 이걸 검토를 안햇어?', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 애국잉출동', ' 애국잉',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋ', ' 대참사ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 이걸 알아채네', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 내부고발자 ㅇㄱㅇ', ' 조짐 ㅋㅋㅋㅋㅋ', ' 엌ㅋㅋㅋㅋ', ' 애국잉', ' 긴급상황!', ' 애국 잉',
#        ' 심히 불------편', ' 왜 바쁜척함', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 찾은스람 ㄹㅇ 열사님임', ' 편-----------안', ' 이정도면 승진각', ' 일뽕나이트',
#        ' wwwwwwwwwwwwwww', ' 대참사 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 일본해 개 에반데',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 포나 안고쳐졌나', ' 저거 썸네일이라 너무 잘보임 ㅋㅋ',
#        ' 컨텐츠 대마왕 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 컨텐츠 갸꿀잼 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋ', ' !업타임',
#        'Twipkr 불효막시무스님 후원 감사해요!', ' 진짜네?', ' 펄-럭',
#        ' 트무원 우정이,40 minutes 22 seconds 동안 일하는중!! :D', ' ㅋㅋㅋㅋㅋ',
#        ' 브금뭔데 ㅋㅋ', ' 일뽕나이트 ㅋㅋㅋㅋㅋㅋ', ' 눈엄청켜졋다', ' 포나 민심터진다',
#        ' 뭔 소리야 이게 ㅋㅋㅋㅋ', ' 상황발생 상황발생', ' 펄럭잉', ' 찾은사람 빛열사님임', ' 민원을 알려줄게',
#        ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', ' 대 참 사',
#        ' 포나 우리나라보다 일본이 더 점유율 높지 않나 절대 수정 안할텐데', ' 브금 뭔데요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#        ' 와 근데 진짜 어떻게 찾은거지'], dtype='<U306')

# %%
from PIL import Image

# %%
import pylab
import imageio
filename = glob.glob('../data/*.mp4')
vid = imageio.get_reader(filename[0],  'ffmpeg')

# %%
import numpy as np
import cv2

# If the input is taken from the camera, pass 0 instead of the video file name.
 
cap = cv2.VideoCapture(filename[0])
 
# Check if camera opened successfully
if (cap.isOpened()== False): 
    print("Error opening video stream or file")

# Read until video is completed
while(cap.isOpened()):
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:

        # Display the resulting frame
        cv2.imshow('Frame',frame)

        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    # Break the loop
    else: 
        break

#When everything done, release the video capture object
cap.release()
 
# Closes all the frames
cv2.destroyAllWindows()

# Define the codec and create VideoWriter object.The output is stored in 'outpy.avi' file.
# Define the fps to be equal to 10. Also frame size is passed.
 
# out = cv2.VideoWriter('outpy.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (frame_width,frame_height))

# %%
nums = [12800, 28700]
for num in nums:
    image = vid.get_data(num)
    fig = pylab.figure()
    fig.suptitle('image #{}'.format(num), fontsize=20)
    pylab.imshow(image)
pylab.show()

# %%
filename
